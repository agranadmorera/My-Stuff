# %%
# Importar librerías para ejecutar ejercicios

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
olympic = pd.read_csv('athlete_events.csv')

# %%
# Definir sexos a través de paleta de azules

sns.scatterplot(x='Age', y='Height', hue='Sex', data=olympic, palette='Blues')
plt.title('Age vs. Height')
# Out:
# Text(0.5, 1.0, 'Age vs. Height')

# %%
# diferenciar Females vs Males utilizando otro tipo de paleta, por ende, colores distintos

sns.scatterplot(x='Age', y='Height', hue='Sex', data=olympic, palette='PuOr')
plt.title('Age vs. Height')
# Out:
# Text(0.5, 1.0, 'Age vs. Height')

# %%
# Estatura de los atletas que compiten

sns.lineplot(x='Age', y='Height', data=olympic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
# Estatura según el sexo de los competidores (atletas)

sns.lineplot(x='Age', y='Height', data=olympic, hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
# Edad para cada atleta:

sns.lineplot(x='Age', y='Height', data=olympic, estimator=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
# Boxplot - edad de los atletas:

sns.boxplot(y=olympic['Age'])
plt.show()

# %%
world2015 = pd.read_csv('world2015.csv')

# %%
price = np.array([10, 45, 30, 15, 50])
std = np.array([2, 5, 8, 3, 1])

plt.xlabel("Stock")
plt.ylabel("Price")
plt.title("Stock Price")
plt.bar(x=[0,1,2,3,4], height=price, yerr = std,
        color="green", width=0.5)

plt.show()

# %%
price = np.array([10, 45, 30, 15, 50])
std = np.array([2, 5, 8, 3, 1])

# Instead of [0,1,2,3,4], put the categories you need for each bar.
x_axis = ["APPLE", "AMAZON", "YAHOO", "GOOGLE", "FACEBOOK"]

plt.xlabel("Stock")
plt.ylabel("Price")
plt.title("Stock Price")
plt.bar(x=x_axis, height=price, yerr = std,
        color="teal", width=0.5)

plt.show()

# %%
price = np.array([10, 45, 30, 15, 50])
std = np.array([2, 5, 8, 3, 1])
x_axis = ["APPLE", "AMAZON", "YAHOO", "GOOGLE", "FACEBOOK"]

plt.xlabel("Stock")
plt.ylabel("Price")
plt.title("Stock Price")
plt.bar(x=x_axis, height=price, yerr = std,
        color="blue", width=0.5)

plt.grid(True)
plt.show()

# %%
# Del Dataset bitcoin se extraen estos gráficos en Matplotlib

bitcoin = pd.read_csv("Bitcoin.csv")
bitcoin.head()
# Out:
#          Date    Price
# 0   2017/10/8  4596.96
# 1  2017/10/15  5697.39
# 2  2017/10/22  5984.96
# 3  2017/10/29  6140.53
# 4   2017/11/5  7382.45

# %%
fig=plt.figure(figsize=(12,8))

plt.grid(True)
plt.plot(bitcoin.Date, bitcoin.Price)
plt.xticks(rotation=30)

for x, y in zip(bitcoin.Date, bitcoin.Price):
    plt.text(x, y, y, ha='center', va='bottom')

# %%
fig=plt.figure(figsize=(15,8))

plt.xticks(rotation=30)
plt.grid(True)
plt.bar(bitcoin.Date, bitcoin.Price)

for x, y in zip(bitcoin.Date, bitcoin.Price):
    plt.text(x, y, y, ha='center', va='bottom')

# %%
# Dataset de World2015

world2015 = pd.read_csv("world2015.csv")
world2015.head()
# Out:
#     Country Continent  Life_expectancy  GDP_per_capita  Population
# 0   Algeria    Africa        75.042537     4132.760292  39871528.0
# 1    Angola    Africa        52.666098     3695.793748  27859305.0
# 2     Benin    Africa        59.720707      783.947091  10575952.0
# 3  Botswana    Africa        64.487415     6532.060501   2209197.0
# 4   Burundi    Africa        57.107049      303.681022  10199270.0
